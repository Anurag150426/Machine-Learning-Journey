# %%
## Exception try,except block
try:
    a=b
except:
    print("The variable is not assigned")
# Out:
# The variable is not assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
result=1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result=1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)   
except Exception as ex1:## this should be always at last 
    print(ex1)
# Out:
# name 'b' is not defined

# %%
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError:
    print("this is not a valid number")
except ZeroDivisionError:
    print("denominator cant be zero")  
except Exception as ex:
    print(ex)
# Out:
# this is not a valid number

# %%
## try,except,else block
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError:
    print("this is not a valid number")
except ZeroDivisionError:
    print("denominator cant be zero")  
except Exception as ex:
    print(ex)    
## else has to work if there is no exception
else:
    print(f"the is result is {result}")
# Out:
# the is result is 3.3333333333333335

# %%
## try,except,else , finally block
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError:
    print("this is not a valid number")
except ZeroDivisionError:
    print("denominator cant be zero")  
except Exception as ex:
    print(ex)    
## else has to work if there is no exception
else:
    print(f"the is result is {result}")   
finally:
    print("Execution completed")
# Out:
# the is result is 0.8333333333333334
# Execution completed

# %%
## File handeling and Exception handeling

try:
    file=open('example1.txt','r')
    content=file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("file does not exist")
except Exception as ex:
    print(ex)


finally:
    if 'file' in locals() or not file.close():
        file.close()
        print('file closed')
# Out:
# name 'b' is not defined
# file closed

# %%
if 'file' in locals():
    print(True)
# Out:
# True
